# %% [markdown]
# # EI manuals Intro
#
# This is a way to share the the practicum manuals from NB2420 Electronic Instrumentation to a larger audience.
#
# The topics are as follows:
#
# - intro testboards
# - intro power supply
# - intro DMM
# - intro scope & triggering
# - intro LTSpice
# - intro ALPACA
