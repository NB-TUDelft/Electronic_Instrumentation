# %% [markdown]
# # ALPACA 2.0
#
# ```{figure} ../images/alpaca/parts.avif
# ---
# max-height: 300px
# name: ALPACA 2.0 Illustrated
# class: no-invert
# ---
# ```
#
# Unlike a real alpaca, ALPACA **(Advanced Learning Platform for Analog Circuits and Automation)** is a device equipped with several digital tools to be your guide in introduction to digital systems and electronics.
#
# ALPACA features:
# - <font color="#1b8700">**Energy Hub:**</font> Pins in the middle of ALPACA to provide voltage to your electrical circuits (+12V, -12V, +3.3V, 5V). **You need to turn on the switch above the pins to provide voltage.**
# - <font color="#002cbb">**Sandbox:**</font> Breadboard, variable resistors and several tools to connect to other devices for creating your own circuits
# - <font color="#bb0016">**Playground:**</font> LEDs, buttons, variable voltage sources and a relay
# - <font color="#b55e01">**Toolkit:**</font> Equipped with tools like voltometer and component tester
# - **2 Raspberry Pico2 microcontrollers:**
#     - <font color="#2d91a0">**Student Pico:**</font> for you to program and be able to create signals/generate signals
#     - <font color="#a02d9c">**Helper Pico:**</font> preprogrammed to control several board's functionalities
#
# <font color="#a02d9c">Helper Pico</font> is located at the top right of the board; whereas, <font color="#2d91a0">Student Pico</font> is located below.
#
# ```{admonition} Connect to Student Pico
# :class: warning
# You must always connect and program <font color="#2d91a0">Student Pico</font>. The <font color="#a02d9c">Helper Pico</font> is meant to be untouched and controls the board on its own.
# ```
#
# ## Getting Started
#
# ALPACA requires to be powered by the **USB-C power port** found on top left and Student Pico needs **Micro-USB** to be connected. Once you turn on the ON/OFF switch ALPACA should power up.
#
# ```{figure} ../images/alpaca/connecting.png
# ---
# max-height: 300px
# name: Connect USB-C to energy hub and Micro USB to Student Pico
# class: no-invert
# ---
# ```
#
# ```{tip}
# You can configure the ALPACA to power on only when a Pico is connected to a computer.
#
# By adjusting the jumper on the `J502` pins located on the top right of the board:
#
# - **Configuration A (Jumper on 1&2):** The board powers on only when both the USB-C power cable is connected and the Pico is connected to a computer.
#
# - **Configuration B (Jumper on 2&3):** The board powers on as long as the USB-C power cable is connected.
# ```
#
# If the screen lights up and displays information, congrats! Your ALPACA is awake!
#
# ### Pins, Jumpers and More
#
# <font color="#ed8600">**Pins**</font> are everywhere on ALPACA they are a <font color="#ed8600">single point of electrical contact for components on the board</font>. Pins functionality is usually written down next to them. You can use cables and jumpers to connect pins.
#
# <font color="#006fed">**Jumpers** are small connectors used to connect two adjacent pins. </font> Connecting certain adjacent pins can **switch settings for instruments** on the ALPACA, for example, enabling a feature or selecting between voltage options...
#
# ```{danger}
# All **GND** pins are connected to the *GROUND (0V)* on the board. **DO NOT** connect a GND pin directly to any voltage pin if you don't want to fry your ALPACA.
# ```
#
# ### Screen and Toolkit
#
# ALPACA is equipped with several tools, these tools use the screen to display information. To cycle between available tools you can use the <font color="#0e4ed9">**FUNCTION button**</font> located next to the screen.
#
# ```{figure} ../images/alpaca/toolkit.png
# ---
# max-height: 300px
# name: Toolkit's pins and all the tools available
# class: no-invert
# ---
# ```
#
# **`VOLT` Voltmeter** reads out the voltage connected to the `VOLTMETER-IN` pin located below the Helper Pico. It can read between voltages +15V and -15V.
#
# ```{figure} ../images/alpaca/voltmeter.png
# ---
# max-width: 150px
# name: Example voltmeter
# class: no-invert
# ---
# ```
#
#
# **`COMP` Component Tester** determines the component type (resistor, capacitor or diode) placed on the `COMPONENT-TESTER` plates or connected to the pins. It is useful to quickly identify resistor's value or a diode's direction.
#
# ```{figure} ../images/alpaca/component_tester.avif
# ---
# max-height: 300px
# name: Toolkit's pins and all the tools available
# class: no-invert
# ---
# ```
#
# **`CSTM` Custom Screen** displays any text defined with the `set_screen_text` function, allowing custom messages or values to be shown on screen.
#
# ```{figure} ../images/alpaca/display_custom_text.png
# ---
# max-width: 150px
# name: Example custom screen
# class: no-invert
# ---
# ```
#
# **`INFO` Information** screen displays information regarding the Helper Pico and a fun message.
#
# ## Source Code
#
# Curious on how ALPACA was programmed? The software is open source and can be found [here](https://github.com/NB-TUDelft/ALPACA).
