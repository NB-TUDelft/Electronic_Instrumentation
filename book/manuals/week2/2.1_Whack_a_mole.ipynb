# %% [markdown]
# # Whack-a-mole

# %% [markdown]
# ```{admonition} How To Work
# :class: important
# The **Preparatory Homework (BAS)** part of this manual should be completed **individually**.
#
# The **Practicum (IC)** part should be completed **in pairs**. During the practicum, divide the workload as equally as possible, for example by letting one student build one part of the circuit while the other student builds the other part, and then swapping roles for measurements and checks.
#
# Throughout this manual, keep your calculations, measurements, sketches, and thoughts in your notepad. The comparison tables from Part C should be completed in your notepad and included in your onepager report for this lab.
# ```

# %% [markdown]
# ## Preparatory homework

# %% [markdown]
# ### Background
#
# (Task_B1_2_1)=
# #### Task B1: What is Whack-a-mole?
# Whack-a-mole is a popular arcade game in which the player uses a mallet/hammer to hit moles as they pop up from random holes. The player is scored based on their reaction time/how quickly they are able to hit the moles.
#
# During this practical, you will be creating your own version of this game on the ALPACA. As the ALPACA has neither moles nor a mallet, you will replace the moles with LEDs and the mallet with buttons. You will programme the LEDs to turn on at random and will use the buttons to turn the LEDs off, analogous to how the mallet is used to hit the moles in the arcade game. You will also measure the reaction time of the player.
#
# (Task_B2_2_1)=
# #### Task B2: Light emitting diodes (LEDs)
# A light emitting diode (LED) is a type of directional component that converts electricity into light. You will dive deeper into the concept of diodes and LEDs in future practicals, but for today, it is only important that you understand how to connect an LED. As seen in the figure below, to conduct electricity and emit light, the long leg of the LED (also referred to as the anode), should be connected to a higher potential than the short leg (also referred to as the cathode).
#
# ```{figure} images/LED.svg
# ---
# width: 300px
# name: LED
# ---
# How to connect an LED
# ```
# As seen in the figure below, the ALPACA has four LEDs. These will act as the moles in your version of Whack-a-mole. The letter A next to the name of each LED represents the anode of the LED and the letter C indicates the cathode.
#
# ```{figure} images/LEDs_ALPACA.png
# ---
# width: 300px
# name: Schematic of LEDs on the ALPACA
# ---
# Schematic of LEDs on the ALPACA, indicating the anode and cathode
# ```
#
# (Task_B3_2_1)=
# #### Task B3: Digital input and output pins
# The ALPACA contains both digital input and digital output pins. These pins are referred to as *digital*, as they are only able to be in one of two states, either high (5 V) or low (0 V). This is in contrast to analogue pins, which can read or output a continuous range of voltages.
#
# Digital output pins output 5 V when set to True and output 0 V when set to False. Similarly, a digital input pin can determine whether 5 V or 0 V are connected. When 5 V are connected to a digital input pin, it will be assigned as True and when 0 V are connected, it will be assigned as False.
#
# To programme a digital input or output pin, you first need to import the Pin function from the machine module MicroPython. This allows you to define pins. You then need to define a pin using the pin ID and state whether the pin is an output or input pin.
#
# ```{tip}
# Pin IDs digital output pins:
# - 10
# - 11
# - 12
# - 13
#
# Pin IDs digital input pins:
# - 14
# - 15
# - 16
# - 17
#
# You can also find the pin IDs in the ALPACA manual.
# ```
#
# Once a digital output pin is defined, it can be programmed as True to output 5 V, or as false to output 0 V and once a digital input pin is defined, it is possible to check whether it is connected to 5V or 0 V.
#
#
# For example, pin 10 on the Pico-Pi is a digital output pin and pin 14 is a digital input pin. In the code cell below, you can see how these pins can be defined and programmed.
#
# ```{note}
# The names Dout1 and Din1 were selected, as they are easy to remember. You can assign different names to the pins.
# ```

# %%
from machine import Pin #Import the module used to define pins

Dout1 = Pin(10, Pin.OUT) #Give the pin a name. Define the pin using the pin ID (in this case, the ID is 10). State whether it is an input/output pin
Din1 = Pin(14, Pin.IN) #Give the pin a name. Define the pin using the pin ID (in this case, the ID is 14). State whether it is an input/output pin

Dout1.value(True) #The value of pin 10 is assigned as True, so it will output 5 V
Dout1.value(False) #The value of pin 10 is assigned as False, so it will output 0 V

isPressed = Din1.value() #The variable isPressed will be True when 5V is connected to pin 10 and False when 0 V are connected to pin 14

# %% [markdown]
# (Task_B4_2_1)=
# #### Task B4: Switches and pull-up/pull-down resistors
# Analogous to the mallet which is used to hit the moles in the Whack-a-mole game, you will use switches to turn off the LEDs. A switch is a valuable electronic component which can be used to close or open a path for current flow. A button is a special type of switch that works when pushed.
#
# As seen in the figure below, the ALPACA has four buttons.
#
# ```{figure} images/switches_ALPACA.png
# ---
# width: 300px
# name: Schematic of switches on the ALPACA
# ---
# Schematic of switches on the ALPACA
# ```
# As you can see in this figure, the circuit containing the button also contains a 10 kΩ resistor.
#
# We have two different options for how we can connect the button with respect to the resistor.
#
# In the figure shown below, the resistor is connected in such a way that we refer to it as a **pull-up resistor**.
#
# ```{figure} images/Pull_up_resistor.svg
# ---
# height: 200px
# name: Pull up resistor
# ---
# Pull-up resistor configuration
# ```
# In this configuration, when the button is not pressed, the digital input pin will be connected to 5 V. This means that the value of the pin will be assigned as True by default. When the button is pressed, the digital input pin will be connected to ground (0 V). The 10 kΩ resistor is connected between the 5 V supply and ground to limit the flow of current, preventing a short circuit when the button is pressed.
#
# We can also connect the resistor as a **pull-down resistor**, as seen in the figure below.
#
# ```{figure} images/Pull_down_resistor.svg
# ---
# height: 200px
# name: Pull down resistor
# ---
# Pull-down resistor configuration
# ```
# In this configuration, when the button is not pressed, the digital input pin will be connected to ground (0 V). This means that the value of the pin will be assigned as False by default. When the button is pressed, the digital input pin will be connected to 5 V. The 10 kΩ resistor is connected between the 5 V supply and ground to limit current flow when the button is pressed, preventing a short circuit.
#
# ```{hint}
# In summary:
# - Pull-up resistor configuration: Default value of the digital input pin (when the button is not pressed) is 5 V or True.
# - Pull-down resistor configuration: Default value of the digital input pin (when the button is not pressed) is 0 V or False.
# - In both configurations, the 10 kΩ resistor limits the flow of current when the button is pressed, preventing a short circuit.
# ```

# %% [markdown]
# ### Anticipate
#
# (Task_A1_2_1)=
# #### Task A1: Connecting an LED to a switch in pull-up vs pull-down configuration
#
# Instead of connecting the output of a switch to a digital input pin, you can also connect it to an LED. This way, you can control the behaviour of the LED by pushing the button.
#
# We will begin by examining the effect of connecting the LED to a button in a pull-up configuration.
#
# Think back to [Task B4](Task_B4_2_1). What is the default output (when the button is not pressed) of a button in a pull-up configuration? What is the output when a button in a pull-up configuration is pressed?
#
# In the figure below, a button with a pull-up resistor is connected to an LED in two different configurations (A and B).
#
# ```{figure} images/Pull_up_switch_LED_config.svg
# ---
# width: 500px
# name: Pull-up button connected to LED in two configurations
# ---
# Schematic of a button with a pull-up resistor connected to an LED in two configurations
# ```
# Consider [Task B2](Task_B2_2_1), for configuration A and configuration B, predict what the LED will do when the button is not pressed and when the button is pressed.
#
# Recall [Task B4](Task_B4_2_1). What is the default output (when the button is not pressed) of a button in a pull-down configuration? What is the output when a button in a pull-down configuration is pressed?
#
# In the figure below, a button with a pull-down resistor is connected to an LED in two different configurations (C and D).
#
# ```{figure} images/Pull_down_switch_config.svg
# ---
# width: 500px
# name: Pull-down button connected to LED in two configurations
# ---
# Schematic of a button with a pull-down resistor connected to an LED in two configurations
# ```
#
# Consider [Task B2](Task_B2_2_1), for configuration A and configuration B, predict what the LED will do when the button is unpressed and when the button is pressed.
#
#
#
# -----
#
# Compare connecting LED to switch in pull-up and pull-down config - validate in I&I1
# Idea is that they understand when output is true and when output is false
#
# Explain that can't implement logic with this yet
#
# Look at connecting switch to digital input pin and connecting digital output pin to the LED
# Explain that this then allows us to do logic: by setting hte output pin to true, we can turn on the LED. When we push the button, we will get a true/false signal (depending on whether have pull-up or pull-down config). Based on this, when get certain signal at input pin, can output something in response from output pin to make LED respond to whatever is happening with the switch
