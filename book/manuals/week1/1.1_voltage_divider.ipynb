# %% [markdown]
# # 1.1: Voltage divider

# %% [markdown]
# ## Preparatory Homework

# %% [markdown]
# ### Background
# ```{admonition} Preparation
# :class: tip
# Before starting this experimet make sure that you are familiar with introductory manuals:
#
# * [Alpaca](../intros/intro_ALPACA.ipynb)
# * [Breadboard](../intros/breadboard.ipynb)
# * [Digital Multimeter](../intros/intro_DMM_Siglent+handheld.ipynb)
# * [TU Delft's test bords](../intros/intro_testboards.ipynb)
# * [Function generator](../intros/intro_function_generator_Siglent.ipynb)
#
# For simulation part of this experiment, follow [LTspice tutorial](../intros/intro_LTSpice.ipynb).
#
# Revisit lecture slides and your notes in case you don't remember:
#
# * How holtage divider works
# * What is Thevenin equivalent circuit
# ```

# %% [markdown]
# ### Anticipate
#
# #### Task 1: Voltage dividers' outputs
# Have a look at the following circut. It is a voltage divider, you shoud be familiar with.
#
# ```{figure} images/voltage_divider.svg
# ---
# name: Voltage divider
# height: 400px
# ---
# Voltage divider circuit.
# ```
# Calculate the outputs of voltage divider powered with $5V$ for the following values of R1 and R2:
# 1. $R1=100\Omega$, $R2=100\Omega$
# 2. $R1=220\Omega$, $R2=220\Omega$
# 3. $R1=1k\Omega$, $R2=1k\Omega$
# 4. $R1=10k\Omega$, $R2=10k\Omega$
# 5. $R1=100k\Omega$, $R2=100k\Omega$
# 6. $R1=1M\Omega$, $R2=1M\Omega$
# 7. $R1=10M\Omega$, $R2=10M\Omega$
# 8. $R1=1k\Omega$, $R2=220\Omega$
#
#
# In your notepad, prepare the following table and fill in the calculated values.
#
# | $R_1$    | $R_2$    | calculated $V_{out}$ [V] | simulated $V_{out}$ [V] | measured $V_{out}$ [V] |
# |:---------|:---------|:-------------------------|:------------------------|:-----------------------|
# | $100 Ω$  | $100 Ω$  |                          |                         |                        |
# | $220 Ω$  | $220 Ω$  |                          |                         |                        |
# | $1 kΩ$   | $1 kΩ$   |                          |                         |                        |
# | $10 kΩ$  | $10 kΩ$  |                          |                         |                        |
# | $100 kΩ$ | $100 kΩ$ |                          |                         |                        |
# | $1 MΩ$   | $1 MΩ$   |                          |                         |                        |
# | $10 MΩ$  | $10 MΩ$  |                          |                         |                        |
# | $1 kΩ$   | $220 Ω$  |                          |                         |                        |

# %% [markdown]
# #### Task 2: Voltage divider, but what about the current?
# Calculate the currents through the resistors, for some selected resistor values form previous task.
#
# | $R_1$    | $R_2$    | calculated $I_{out}$ [A] | simulated $I_{out}$ [A] | measured $I_{out}$ [A] |
# |:---------|:---------|:--------------------------|:-------------------------|:------------------------|
# | $100 Ω$  | $100 Ω$  |                           |                          |                         |
# | $10 kΩ$  | $10 kΩ$  |                           |                          |                         |
# | $10 MΩ$  | $10 MΩ$  |                           |                          |                         |

# %% [markdown]
# #### Task 3: How to deal with a range of LOAD resistors?
#
# The function generator can be seen as ideal voltage source, with an internal resistance (inside the device). The generated voltage is then divided over the (fixed) internal and the external resistor (termed LOAD resistor). This includes everything inside the circuit that you attach to the function generator.
#
# ```{figure} images/function_generator_load_resistor.svg
# ---
# name: Function generator with load resistor
# height: 400px
# ---
# Function generator with load resistor.
# ```
#
# Look at the figure above, try answering following questions, make sure to note them down:
# 1. Does this circuit reasemble any of a circuits we have seen before?
# 2. Where we will be meusuring the voltage?
# 3. Will the value of load resistor cause measured voltage to diverge from the set value?
# 4. Come up with a (qualitative) solution how the function generator (with internal restance) can work with a wide range of LOAD resistors, for example $50 Ω$ and $10 MΩ$.

# %% [markdown]
# #### Task 4: More complex circuits with voltage dividers
# Below there are 3 circuits with voltage dividers. For each circuit calculate the voltage between output terminal and the circuit ground. Give the values of Thevenin resistances and voltages for 2 of the circuits.
#
# ```{figure} images/stacked_dividers.svg
# ---
# height: 300px
# ---
# Voltage dividers in series.
# ```
#
# ```{figure} images/two_dividers_thevinen.svg
# ---
# height: 300px
# ---
# Voltage dividers in parallel.
# ```

# %% [markdown]
# #### Task 5: Distinguish $V_{pp}$, $V_p$, $V_{rms}$
# While generating a sine wave, the function generator is most often set to $V_{pp}$ (volt peak-to-peak). The DMM measures $V_{rms}$ (volt root-mean-square).
#
# From a sine wave with amplitude $V_p = 1\,\mathrm{V}$, the peak-to-peak value is $V_{pp} = 2\,\mathrm{V}$. The $V_{rms}$ is the continuous DC signal having the same power as the time-varying AC signal, the quadratic mean. The $V_{rms}$ of this sine wave is $V_{rms} = 1/\sqrt{2}\,\mathrm{V} \approx 0.71\,\mathrm{V}$.
#
#
# ```{figure} images/Vpp_Vp_Vrms.png
# ---
# name: vpp-vrms
# ---
# Oscilloscope showing the sine wave
# ```
# The function generator generates the signal above. Derive the amplitude of the signal in $V_{rms}$, $V_p$, and $V_{pp}$. Also derive the frequency of the sine wave.
