# %% [markdown]
# # 1.1: Voltage divider

# %% [markdown]
# ## Preparatory Homework

# %% [markdown]
# ### Background
# ```{admonition} Preparation
# :class: tip
# Before starting this experiment make sure that you are familiar with introductory manuals:
#
# * [Alpaca](../intros/intro_ALPACA.ipynb)
# * [Breadboard](../intros/breadboard.ipynb)
# * [Digital Multimeter](../intros/intro_DMM_Siglent+handheld.ipynb)
# * [TU Delft's test boards](../intros/intro_testboards.ipynb)
# * [Function generator](../intros/intro_function_generator_Siglent.ipynb)
#
# For simulation part of this experiment, follow [LTspice tutorial](../intros/intro_LTSpice.ipynb).
#
# Revisit lecture slides and your notes in case you don't remember:
#
# * How voltage divider works
# * What is Thevenin equivalent circuit
# ```

# %% [markdown]
# ### Anticipate
#
# #### Task A1: Voltage dividers' outputs
# Have a look at the following circuit. It is a voltage divider, you should be familiar with.
#
# ```{figure} images/voltage_divider.svg
# ---
# name: Voltage divider
# height: 400px
# ---
# Voltage divider circuit
# ```
# Calculate the outputs of voltage divider powered with $5V$ for the following values of R1 and R2:
# 1. $R1=100\Omega$, $R2=100\Omega$
# 2. $R1=220\Omega$, $R2=220\Omega$
# 3. $R1=1k\Omega$, $R2=1k\Omega$
# 4. $R1=10k\Omega$, $R2=10k\Omega$
# 5. $R1=100k\Omega$, $R2=100k\Omega$
# 6. $R1=1M\Omega$, $R2=1M\Omega$
# 7. $R1=10M\Omega$, $R2=10M\Omega$
# 8. $R1=1k\Omega$, $R2=220\Omega$
#
#
# In your notepad, prepare the following table and fill in the calculated values.
#
# | $R_1$    | $R_2$    | calculated $V_{out}$ [V] | simulated $V_{out}$ [V] | measured $V_{out}$ [V] |
# |:---------|:---------|:-------------------------|:------------------------|:-----------------------|
# | $100 Ω$  | $100 Ω$  |                          |                         |                        |
# | $220 Ω$  | $220 Ω$  |                          |                         |                        |
# | $1 kΩ$   | $1 kΩ$   |                          |                         |                        |
# | $10 kΩ$  | $10 kΩ$  |                          |                         |                        |
# | $100 kΩ$ | $100 kΩ$ |                          |                         |                        |
# | $1 MΩ$   | $1 MΩ$   |                          |                         |                        |
# | $10 MΩ$  | $10 MΩ$  |                          |                         |                        |
# | $1 kΩ$   | $220 Ω$  |                          |                         |                        |

# %% [markdown]
# #### Task A2: Voltage divider, but what about the current?
# Calculate the currents through the resistors, for some selected resistor values form previous task.
#
# | $R_1$    | $R_2$    | calculated $I_{out}$ [A] | simulated $I_{out}$ [A] | measured $I_{out}$ [A] |
# |:---------|:---------|:--------------------------|:-------------------------|:------------------------|
# | $100 Ω$  | $100 Ω$  |                           |                          |                         |
# | $10 kΩ$  | $10 kΩ$  |                           |                          |                         |
# | $10 MΩ$  | $10 MΩ$  |                           |                          |                         |

# %% [markdown]
# #### Task A3: How to deal with a range of LOAD resistors?
#
# The function generator can be seen as ideal voltage source, with an internal resistance (inside the device). The generated voltage is then divided over the (fixed) internal and the external resistor (termed LOAD resistor). This includes everything inside the circuit that you attach to the function generator.
#
# ```{figure} images/function_generator_load_resistor.svg
# ---
# name: Function generator with load resistor
# height: 400px
# ---
# Function generator with load resistor
# ```
#
# Look at the figure above, try answering following questions, make sure to note them down:
# 1. Does this circuit resemble any of the circuits we have seen before?
# 2. Where will we be measuring the voltage?
# 3. Will the value of load resistor cause measured voltage to diverge from the set value?
# 4. Come up with a (qualitative) solution how the function generator (with internal resistance) can work with a wide range of LOAD resistors, for example $50 Ω$ and $10 MΩ$.

# %% [markdown]
# #### Task A4: More complex circuits with voltage dividers
# Below there are 3 circuits with voltage dividers. For each circuit calculate the voltage between output terminal and the circuit ground. Give the values of Thevenin resistances and voltages for 2 of the circuits.
#
# ```{figure} images/stacked_dividers.svg
# ---
# height: 300px
# name: fig-stacked-dividers
# ---
# Voltage dividers in series
# ```
#
# ```{figure} images/two_dividers_thevinen.svg
# ---
# height: 300px
# name: fig-two-dividers-thevinen
# ---
# Voltage dividers in parallel
# ```

# %% [markdown]
# #### Task A5: Distinguish $V_{pp}$, $V_p$, $V_{rms}$
# While generating a sine wave, the function generator is most often set to $V_{pp}$ (volt peak-to-peak). The DMM measures $V_{rms}$ (volt root-mean-square).
#
# ```{figure} images/Vpp_Vp_Vrms.png
# ---
# name: vpp-vrms
# class: no-invert
# ---
# Oscilloscope showing the sine wave
# ```
# The function generator generates the signal above. Derive the amplitude of the signal in $V_{rms}$, $V_p$, and $V_{pp}$. Also derive the frequency of the sine wave.
#
# ```{admonition} Check your answer
# :class: answer, dropdown
# From a sine wave with amplitude $V_p = 1\,\mathrm{V}$, the peak-to-peak value is $V_{pp} = 2\,\mathrm{V}$. The $V_{rms}$ is the continuous DC signal having the same power as the time-varying AC signal, the quadratic mean. The $V_{rms}$ of this sine wave is $V_{rms} = \frac{1}{\sqrt{2}}\,\mathrm{V} \approx 0.71\,\mathrm{V}$.
# ```

# %% [markdown]
# #### Task A6: Which DMM range gives the best accuracy?
#
# A $5\,\frac{1}{2}$-digit DMM shows $5$ full digits plus one extra leading digit that can only be $0$ or $1$.
# So on the highest range it counts from $0$ to $199999$.
# The accuracy of the $5\,\frac{1}{2}$-digit DMM is specified by the manufacturer as $\pm(0.025\% + 0.005\%) = \pm(\text{reading}\% + \text{range}\%)$.
#
# 1. Calculate the accuracy for a measurement of $1.2\,\mathrm{V}$ on the $2\,\mathrm{V}$ range.
# 2. Calculate the accuracy for a measurement of $1.2\,\mathrm{V}$ on the $20\,\mathrm{V}$ range.
# 3. Explain which range is preferred for optimally measuring $1.2\,\mathrm{V}$ and why.
#
# For this task, use the following details about the ranges:
# - $2\,\mathrm{V}$ range ($3\,\frac{1}{2}$-digit DMM): max $1.999\,\mathrm{V}$, min $0.001\,\mathrm{V}$.
# - $20\,\mathrm{V}$ range ($3\,\frac{1}{2}$-digit DMM): max $19.99\,\mathrm{V}$, min $0.01\,\mathrm{V}$.
# - With the same number of digits, each range has a different number of decimal places.
#
# ```{admonition} Check your answer
# :class: answer, dropdown
# For $1.2\,\mathrm{V}$, the accuracy is $\pm 0.025\% \cdot 1.2 + 0.005\% \cdot 2\,\mathrm{V} = \pm0.4\,\mathrm{mV}$.
# ```

# %% [markdown]
# ### Simulate
# ```{attention}
# Since this is first week, try your best to simulate circuits, in case something goes wrong, don't worry, you can ask teaching assistant for help, during practical session.
# ```
# #### Recap how to use LTspice
# `````{tab-set}
#
# ````{tab-item} Windows
# ```{video} https://www.youtube.com/embed/thtkBIETRvU
# ```
# Watch video, in second part of the video you can see how to use LTspice on Windows.
# ````
#
# ````{tab-item} macOS
# ```{video} https://www.youtube.com/embed/IvnaiMVzhMA
# ```
# Watch video, in second part of the video you can see how to use LTspice on macOS.
# ````
# `````
#
# #### Task S1: Simple voltage divider
# In tasks A1 and A2, you conducted some calculations. Now it's time to simulate the circuit and verify your results. You can build the circuit in LTspice once, then adjust the resistors' values and simulate again. For $R1$ & $R2$ values of $100\,\Omega$, $10\,\mathrm{k}\Omega$, and $10\,\mathrm{M}\Omega$ you can also measure current through the resistors at the same time, to avoid simulating the circuit again.
#
# ```{figure} images/voltage_divider.svg
# ---
# name: Voltage_divider2
# height: 400px
# ---
# Voltage divider circuit
# ```
# Continue filling in the table for voltages, we started in task A1:
#
# | $R_1$    | $R_2$    | calculated $V_{out}$ [V] | simulated $V_{out}$ [V] | measured $V_{out}$ [V] |
# |:---------|:---------|:-------------------------|:------------------------|:-----------------------|
# | $100 Ω$  | $100 Ω$  |                          |                         |                        |
# | $220 Ω$  | $220 Ω$  |                          |                         |                        |
# | $1 kΩ$   | $1 kΩ$   |                          |                         |                        |
# | $10 kΩ$  | $10 kΩ$  |                          |                         |                        |
# | $100 kΩ$ | $100 kΩ$ |                          |                         |                        |
# | $1 MΩ$   | $1 MΩ$   |                          |                         |                        |
# | $10 MΩ$  | $10 MΩ$  |                          |                         |                        |
# | $1 kΩ$   | $220 Ω$  |                          |                         |                        |
#
# Continue filling in the table for currents, we started in task A2:
#
# | $R_1$    | $R_2$    | calculated $I_{out}$ [A] | simulated $I_{out}$ [A] | measured $I_{out}$ [A] |
# |:---------|:---------|:--------------------------|:-------------------------|:------------------------|
# | $100 Ω$  | $100 Ω$  |                           |                          |                         |
# | $10 kΩ$  | $10 kΩ$  |                           |                          |                         |
# | $10 MΩ$  | $10 MΩ$  |                           |                          |                         |

# %% [markdown]
# #### Task S2: Use LTspice to build the simulation of connected voltage dividers
# Simulate these circuits introduced in task A4, and check whether your output voltage calculations are correct.
# To make this task quicker, build the basic dividers first, then connect them in three different ways.
#
# ```{figure} images/stacked_dividers.svg
# ---
# height: 300px
# name: fig-stacked-dividers2
# ---
# Voltage dividers in series
# ```
#
# ```{figure} images/two_dividers_thevinen.svg
# ---
# height: 300px
# name: fig-two-dividers-thevinen2
# ---
# Voltage dividers in parallel
# ```

# %% [markdown]
# ## Practicum
# ### Implement and investigate
# #### Task I1: Building simple voltage dividers on a breadboard
# Using the breadboard, cables and resistors, build a voltage divider circuit. Remeber to connect power rails of a breadboard to the power source. Ypu can build circuits next to each other, but preferably go one by one, to ensure that the measurements are unbiased.
#
# ```{figure} images/voltage_divider.svg
# ---
# name: Voltage_divider3
# height: 400px
# ---
# Voltage divider circuit
# ```
#
# After building the circuit, measure the voltage at the output of the divider and fill in empty cells in the table:
#
# | $R_1$    | $R_2$    | calculated $V_{out}$ [V] | simulated $V_{out}$ [V] | measured $V_{out}$ [V] |
# |:---------|:---------|:-------------------------|:------------------------|:-----------------------|
# | $100 Ω$  | $100 Ω$  |                          |                         |                        |
# | $220 Ω$  | $220 Ω$  |                          |                         |                        |
# | $1 kΩ$   | $1 kΩ$   |                          |                         |                        |
# | $10 kΩ$  | $10 kΩ$  |                          |                         |                        |
# | $100 kΩ$ | $100 kΩ$ |                          |                         |                        |
# | $1 MΩ$   | $1 MΩ$   |                          |                         |                        |
# | $10 MΩ$  | $10 MΩ$  |                          |                         |                        |
# | $1 kΩ$   | $220 Ω$  |                          |                         |                        |

# %% [markdown]
# #### Task I2: Currents
# Using DMM set in current mode, measure the currents in the circuits, fill in the table below, you can try measuring in different places of the circuit:
#
# | $R_1$    | $R_2$    | calculated $I_{out}$ [A] | simulated $I_{out}$ [A] | measured $I_{out}$ [A] |
# |:---------|:---------|:--------------------------|:-------------------------|:------------------------|
# | $100 Ω$  | $100 Ω$  |                           |                          |                         |
# | $10 kΩ$  | $10 kΩ$  |                           |                          |                         |
# | $10 MΩ$  | $10 MΩ$  |                           |                          |                         |

# %% [markdown]
# #### Task I3: Preparation for tasks I4 and I5
# Build following voltage dividers, keep them both on a breadboard and measure the voltages at the output of each divider.
#
# ::::{div} hstack-grid
#
# ```{figure} images/voltage_divider_1k_220.svg
# ---
# name: Voltage_divider_1k_220
# height: 300px
# ---
# Voltage divider circuit with 1kOhm and 220Ohm resistors
# ```
#
# ```{figure} images/voltage_divider_10k.svg
# ---
# name: Voltage_divider_10k
# height: 300px
# ---
# Voltage divider circuit with 10kOhm resistors
# ```
#
# ::::

# %% [markdown]
# #### Task I4: Connect divider outputs (parallel dividers)
# Connect the two divider outputs and complete the circuit as shown below. Measure the output voltage and write down your result.
#
# ```{figure} images/two_dividers_thevinen.svg
# ---
# height: 300px
# name: fig-two-dividers-thevinen-i4
# ---
# Voltage dividers in parallel
# ```
#
# #### Task I5: Stack dividers in series
# Connect the dividers in series as shown below. Measure the output voltage and write down your result.
#
# ```{figure} images/stacked_dividers.svg
# ---
# height: 300px
# name: fig-stacked-dividers-i5
# ---
# Voltage dividers in series
# ```

# %% [markdown]
# #### Task I6: Measure $V_{rms}$ with a digital multimeter
# Set up the function generator output so you can measure it with the DMM.
#
# ```{figure} images/function_generator_tb1_dmm.avif
# ---
# name: fig-function-generator-tb1-dmm
# class: no-invert
# ---
# Function generator output connected to the DMM and to test board 1
# ```
#
# - Connect the function generator output to the DMM and to test board 1 using a BNC T-splitter and a BNC-to-banana adapter or cable.
# - Make sure the BNC signal line goes to the red input and the shield to COM.
# - Do not connect the BNC to any other components on the board.
# - Set the function generator to a sine wave of $1\,\mathrm{kHz}$ and amplitude $2\,\mathrm{V}_{rms}$.
# - Measure the voltage with the DMM.
#
# **Questions to answer**:
# 1. Which type of voltage does the DMM display: $V_{pp}$, $V_p$, or $V_{rms}$?
# 2. If you set $2\,\mathrm{V}_{rms}$ on the generator, what does the DMM read?
# 3. Predict what happens if you connect an external load resistor: will the measured voltage increase, decrease, or stay the same?

# %% [markdown]
# #### Task I7: Load effects and output setup
# In Task A3 you discussed the function generator internal resistance and the effect of the load. Now verify this with measurements.
#
# ```{figure} images/rotary_switch.svg
# ---
# name: Rotary switch
# height: 500px
# ---
# Schematic of the rotary switch and BNC connectors on the test board.
# ```
#
# ##### Part A: Rotary switch load
# - Keep the function generator at $2\,\mathrm{V}_{rms}$ and $1\,\mathrm{kHz}$ sine.
# - Connect the rotary switch (SW1) as a load and measure $V_{rms}$ across it with the DMM.
# - Find the switch setting (and resistance value) where the DMM reads the correct $V_{rms}$.
# - Find the setting where the DMM reads approximately $\frac{V_{supply}}{2}$.
# - Record the switch position and resistance value for both cases.
#
# ##### Part B: Output setup
# The function generator has an OUTPUT SETUP that compensates for the expected load.
# - Locate UTILITY / OUTPUT SETUP and choose either HIGH Z or $50\,\Omega$.
# - With the test board connected and the rotary switch set to the position closest to $50\,\Omega$, decide which load setting gives the correct $V_{rms}$. Record the setting and the measured values.
# - Disconnect the test board (no external load). Decide which load setting gives the correct $V_{rms}$. Record the setting and the measured values.
#
# ```{admonition} Hint
# :class: hint, dropdown
# HIGH Z assumes a very large load (e.g., DMM), while $50\,\Omega$ assumes a low load. Match the setting to the actual load so the displayed amplitude is correct.
# ```
