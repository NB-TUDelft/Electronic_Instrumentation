# %% [markdown]
# # 1.1: Voltage divider

# %% [markdown]
# ```{attention}
# Before starting this experimet make sure that you are familiar with ALPACA: [introduction manual](../intros/intro_ALPACA.ipynb)
# ```

# %% [markdown]
# ## Background
# Before buiding the voltage divider lets recap how you can make connections on a circuit board.
# ```{figure} images/breadboard-horizontal-rows.png
# ---
# height: 300px
# name: Breadboard horizontal rows
# ---
# Horizontal rows of contacts on a breadboard are connected together, this allows for eazy wiring of components.
# ([<small>https://computers.tutsplus.com/tutorials/how-to-use-a-breadboard-and-build-a-led-circuit--mac-54746</small>](https://computers.tutsplus.com/tutorials/how-to-use-a-breadboard-and-build-a-led-circuit--mac-54746))
# ```
# ```{figure} images/breadboard-vertical-power.png
# ---
# height: 300px
# name: Breadboard vertical power
# ---
# ([<small>https://computers.tutsplus.com/tutorials/how-to-use-a-breadboard-and-build-a-led-circuit--mac-54746</small>](https://computers.tutsplus.com/tutorials/how-to-use-a-breadboard-and-build-a-led-circuit--mac-54746))
# On each side of the breadboard there are power rails, these can be connected to the power source and can be used to power components on the breadboard.
# ```
