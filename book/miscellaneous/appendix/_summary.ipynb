# %% [markdown]
# # Appendix

# %% [markdown]
# This appendix contains additional explanations (in case you want to read different explanation than one in the book), extracurricular topics, fun facts and maybe some easter eggs.

# %% [markdown]
# * [Resistance recap](resistance.ipynb): Ohm's law, resistor networks, and resistance measurements.
# * [Ground loops](ground_loops.ipynb): return-current paths, measurement errors, and grounding the bridge measurement.
